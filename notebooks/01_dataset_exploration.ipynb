# %%
import sys
import scanpy as sc

print("Python:")
print(sys.executable)

print("\nScanpy:")
print(sc.__version__)
# Out:
# Python:
# /Users/Tommy/Documents/GitHub/ImmunoType/.venv/bin/python3.12
#
# Scanpy:
# 1.12.2
# /var/folders/8g/sx7vtp551gv00j8kmvm1rl3w0000gq/T/ipykernel_24220/1753354158.py:8: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(sc.__version__)

# %%
adata = sc.datasets.pbmc3k()
adata
# 2700 cells x 32728 genes
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'
#     layers: None (.X)

# %%
# inspect cell metadata
adata.obs.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [AAACATACAACCAC-1, AAACATTGAGCTAC-1, AAACATTGATCAGC-1, AAACCGTGCTTCCG-1, AAACCGTGTATGCG-1]

# %%
adata.obs.columns
# Out:
# Index([], dtype='str')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2700 × 32738
#     var: 'gene_ids'
#     layers: None (.X)

# %%
adata.uns.keys()
# Out:
# odict_keys([])

# %%
adata.var.head()
# Out:
#                      gene_ids
# index
# MIR1302-10    ENSG00000243485
# FAM138A       ENSG00000237613
# OR4F5         ENSG00000186092
# RP11-34P13.7  ENSG00000238009
# RP11-34P13.8  ENSG00000239945

# %%
adata.X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float32'
# 	with 2286884 stored elements and shape (2700, 32738)>

# %%
type(adata.X)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
adata.n_obs
# Out:
# 2700

# %%
adata.n_vars
# Out:
# 32738
